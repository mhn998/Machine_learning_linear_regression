# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Load the data you receive into a Pandas DataFrame.
# Show the first five rows of the data set.
df = pd.read_csv('./CO2_Emissions_Canada.csv')
df.head(5)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
# Show the description and the info of the data set.
print(df.describe())
print(df.info())
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
X = df['Fuel Consumption Comb (L/100 km)'].values.reshape(-1,1)
X
# Out:
# array([[ 8.5],
#        [ 9.6],
#        [ 5.9],
#        ...,
#        [10.3],
#        [ 9.9],
#        [10.7]])

# %%
y = df['CO2 Emissions(g/km)'].values
y
# Out:
# array([196, 221, 136, ..., 240, 232, 248])

# %%
# Using a regression model, split your data into train and test data.
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=2020)
X_train
# Out:
# array([[13.9],
#        [13.4],
#        [15.6],
#        ...,
#        [ 7.9],
#        [12.1],
#        [17.3]])

# %%
plt.scatter(X_train, y_train, color='blue')
plt.xlabel('CO2 Emissions(g/km)')
plt.ylabel('Fuel Consumption Comb (L/100 km)')
plt.show()

# %%
# Fit your training split to the regression model.
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(X_test)
y_hat
# Out:
# array([215.61818747, 206.29524478, 187.64935939, ..., 204.43065624,
#        239.85783847, 362.92068199])

# %%
y_test
# Out:
# array([209, 200, 178, ..., 199, 239, 396])

# %%
# Show your regression model’s score
print(f'{model.score(x_train, y_train)*100}%')
# Out:
# 84.3292920987637%

# %%
plt.scatter(x_train, y_train, color='blue')
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_predict, color='green')
plt.xlabel('CO2 Emissions(g/km)')
plt.ylabel('Fuel Consumption Comb (L/100 km)')
plt.show()

# %% [markdown]
# ### Draw at least three conclusions from your regression model
# 1. we can control the amount of acceptable co2 emmissions that will not affect the environment by simply traversing the questions of fuel consumption limitation , that can help with better environment and manufacturing.
# 2. The more fuel consumption  , the more co2 emmissions
# 3. Go for electrical cars !! :D , I mean when we have the relation we can build on that and go for another alternatives, also from co2 emmission we can do some economic calculations based on the price of fuel  and search for a good alternative or just improve the efficiency of motors by reducing its consumption of fuel.
